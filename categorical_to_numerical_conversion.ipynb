# %%
1.label encoding
2.one hot encoding
3.ordinal encoding
4.frequency encoding
5.target encoding(mean encoding)

# %%
#label encoding
from sklearn.preprocessing import LabelEncoder
data=['Low','Medium','High','Medium','Low','High']
encoder=LabelEncoder()
encoded_data=encoder.fit_transform(data)
print("encoded Data:",encoded_data)
# Out:
# encoded Data: [1 2 0 2 1 0]

# %%
#One-Hot encoding
import pandas as pd
df=pd.DataFrame({'Color':['Red','Blue','Green','Red','Green','violet']})
df_encoded=pd.get_dummies(df,columns=['Color'])
df_encoded
# Out:
#    Color_Blue  Color_Green  Color_Red  Color_violet
# 0       False        False       True         False
# 1        True        False      False         False
# 2       False         True      False         False
# 3       False        False       True         False
# 4       False         True      False         False
# 5       False        False      False          True
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# df_encoded.groupby('Color_Blue').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# df_encoded.groupby('Color_Green').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# df_encoded.groupby('Color_Red').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# df_encoded.groupby('Color_violet').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Color_Green'].value_counts()
#     for x_label, grp in df_encoded.groupby('Color_Blue')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Color_Blue')
# _ = plt.ylabel('Color_Green')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Color_Red'].value_counts()
#     for x_label, grp in df_encoded.groupby('Color_Green')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Color_Green')
# _ = plt.ylabel('Color_Red')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Color_violet'].value_counts()
#     for x_label, grp in df_encoded.groupby('Color_Red')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Color_Red')
# _ = plt.ylabel('Color_violet')
